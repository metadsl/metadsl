# %% [markdown]
# # Tests
# In this notebook, we run our `pytest` test suite. Why would we run this in a notebook not from the command line? Because then  we can visualize the replacemnts as they happen for debugging

# %%
import pytest
import metadsl_visualize
DISABLED_PLUGINS = [
    "xdist",
    "mypy",
    "pudb",
    "testmon",
    "randomly",
    "forked"
]

def test(path=""):
    pytest.main([l for p in DISABLED_PLUGINS for l in ("-p", f"no:{p}")] + ["-v", "-s", path])
    
test("metadsl_core/function_test.py::TestFunction")
# Out:
# ========================================================= test session starts =========================================================
# platform darwin -- Python 3.7.3, pytest-4.4.0, py-1.8.0, pluggy-0.9.0 -- /usr/local/miniconda3/envs/metadsl/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/saul/p/metadsl, inifile: pytest.ini
# plugins: xdist-1.29.0, cov-2.6.1, nbval-0.9.1, metadsl-visualize-0.0.0
# collecting ... collected 4 items
#
# metadsl_core/function_test.py::TestFunction::test_one_recursive_call
# Typez(definitions=None, nodes={'-531802230055144055': PrimitiveNode(type='function', repr='<function TestFunction.test_one_recursive_call.<locals>.factorial at 0x10e19ef28>'), '7104186953136895503': CallNode(function='metadsl_core.function.FunctionOne.from_fn_recursive', type_params=None, args=['-531802230055144055'], kwargs=None), '-8909088244517995247': PrimitiveNode(type='int', repr='0'), '-4050196712294610884': CallNode(function='metadsl_core.integer.Integer.from_int', type_params=None, args=['-8909088244517995247'], kwargs=None), '4370199804330644629': CallNode(function='metadsl_core.function.FunctionOne.__call__', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['7104186953136895503', '-4050196712294610884'], kwargs=None), '1908367311938994852': PrimitiveNode(type='str', repr="'factorial'"), '-531802216116552155': PrimitiveNode(type='function', repr='<function FunctionOne.from_fn_recursive.<locals>.inner at 0x10e1a8268>'), '4486499225868221542': CallNode(function='metadsl_core.abstraction.Abstraction.from_fn', type_params=None, args=['-531802216116552155'], kwargs=None), '5677710838696510770': CallNode(function='metadsl_core.abstraction.Abstraction.fix', type_params=None, args=['4486499225868221542'], kwargs=None), '-1701452941616683687': CallNode(function='metadsl_core.function.FunctionOne.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['1908367311938994852', '5677710838696510770'], kwargs=None), '-2882309741471664568': CallNode(function='metadsl_core.function.FunctionOne.__call__', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-1701452941616683687', '-4050196712294610884'], kwargs=None), '-2378088374876498411': PrimitiveNode(type='metadsl_core.abstraction.Variable', repr='Variable(4531600464)'), '-1131929806638912522': CallNode(function='metadsl_core.abstraction.Abstraction.create_variable', type_params={'U': DeclaredTypeInstance(type='metadsl_core.abstraction.Abstraction', params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}), 'T': DeclaredTypeInstance(type='metadsl_core.abstraction.Abstraction', params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)})}, args=['-2378088374876498411'], kwargs=None), '-531802216087323980': PrimitiveNode(type='function', repr='<function FunctionOne.from_fn_recursive.<locals>.inner.<locals>.inner_inner at 0x10e1a8598>'), '7148079765066192533': CallNode(function='metadsl_core.abstraction.Abstraction.from_fn', type_params=None, args=['-531802216087323980'], kwargs=None), '8200998516221084275': CallNode(function='metadsl_core.abstraction.Abstraction.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.abstraction.Abstraction', params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}), 'T': DeclaredTypeInstance(type='metadsl_core.abstraction.Abstraction', params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)})}, args=['-1131929806638912522', '7148079765066192533'], kwargs=None), '-2628751676476385888': CallNode(function='metadsl_core.abstraction.Abstraction.fix', type_params=None, args=['8200998516221084275'], kwargs=None), '-1587769026722158381': CallNode(function='metadsl_core.function.FunctionOne.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integ ...
# Typez(definitions=None, nodes={'-531802230055144055': PrimitiveNode(type='function', repr='<function TestFunction.test_one_recursive_call.<locals>.factorial at 0x10e19ef28>'), '7104186953136895503': CallNode(function='metadsl_core.function.FunctionOne.from_fn_recursive', type_params=None, args=['-531802230055144055'], kwargs=None), '-8909088244516912722': PrimitiveNode(type='int', repr='1'), '1014978254107297921': CallNode(function='metadsl_core.integer.Integer.from_int', type_params=None, args=['-8909088244516912722'], kwargs=None), '-4592975649763411745': CallNode(function='metadsl_core.function.FunctionOne.__call__', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['7104186953136895503', '1014978254107297921'], kwargs=None), '1908367311938994852': PrimitiveNode(type='str', repr="'factorial'"), '8691569820645126503': PrimitiveNode(type='function', repr='<function FunctionOne.from_fn_recursive.<locals>.inner at 0x10e1a8c80>'), '-4952756114315809874': CallNode(function='metadsl_core.abstraction.Abstraction.from_fn', type_params=None, args=['8691569820645126503'], kwargs=None), '7196997905096546295': CallNode(function='metadsl_core.abstraction.Abstraction.fix', type_params=None, args=['-4952756114315809874'], kwargs=None), '-4505566019388168155': CallNode(function='metadsl_core.function.FunctionOne.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['1908367311938994852', '7196997905096546295'], kwargs=None), '-2915577726447176096': CallNode(function='metadsl_core.function.FunctionOne.__call__', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-4505566019388168155', '1014978254107297921'], kwargs=None), '-2378088349411180311': PrimitiveNode(type='metadsl_core.abstraction.Variable', repr='Variable(4531715600)'), '3182976192428355204': CallNode(function='metadsl_core.abstraction.Abstraction.create_variable', type_params={'U': DeclaredTypeInstance(type='metadsl_core.abstraction.Abstraction', params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}), 'T': DeclaredTypeInstance(type='metadsl_core.abstraction.Abstraction', params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)})}, args=['-2378088349411180311'], kwargs=None), '8691569820546616728': PrimitiveNode(type='function', repr='<function FunctionOne.from_fn_recursive.<locals>.inner.<locals>.inner_inner at 0x10e1a8950>'), '1555532176685261482': CallNode(function='metadsl_core.abstraction.Abstraction.from_fn', type_params=None, args=['8691569820546616728'], kwargs=None), '6970038109383711605': CallNode(function='metadsl_core.abstraction.Abstraction.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.abstraction.Abstraction', params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}), 'T': DeclaredTypeInstance(type='metadsl_core.abstraction.Abstraction', params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)})}, args=['3182976192428355204', '1555532176685261482'], kwargs=None), '-2187727140368258790': CallNode(function='metadsl_core.abstraction.Abstraction.fix', type_params=None, args=['6970038109383711605'], kwargs=None), '916139923662574736': CallNode(function='metadsl_core.function.FunctionOne.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', ...
# Typez(definitions=None, nodes={'-531802230055144055': PrimitiveNode(type='function', repr='<function TestFunction.test_one_recursive_call.<locals>.factorial at 0x10e19ef28>'), '7104186953136895503': CallNode(function='metadsl_core.function.FunctionOne.from_fn_recursive', type_params=None, args=['-531802230055144055'], kwargs=None), '-8909088244519077772': PrimitiveNode(type='int', repr='3'), '-3805158875542524266': CallNode(function='metadsl_core.integer.Integer.from_int', type_params=None, args=['-8909088244519077772'], kwargs=None), '1365321843960783670': CallNode(function='metadsl_core.function.FunctionOne.__call__', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['7104186953136895503', '-3805158875542524266'], kwargs=None), '1908367311938994852': PrimitiveNode(type='str', repr="'factorial'"), '-531802216132790030': PrimitiveNode(type='function', repr='<function FunctionOne.from_fn_recursive.<locals>.inner at 0x10e1a8378>'), '-1520738032759815563': CallNode(function='metadsl_core.abstraction.Abstraction.from_fn', type_params=None, args=['-531802216132790030'], kwargs=None), '-8072556466256069202': CallNode(function='metadsl_core.abstraction.Abstraction.fix', type_params=None, args=['-1520738032759815563'], kwargs=None), '-321351883467321407': CallNode(function='metadsl_core.function.FunctionOne.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['1908367311938994852', '-8072556466256069202'], kwargs=None), '-8311054913800056101': CallNode(function='metadsl_core.function.FunctionOne.__call__', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-321351883467321407', '-3805158875542524266'], kwargs=None), '6845283599498181972': PrimitiveNode(type='metadsl_core.abstraction.Variable', repr='Variable(4532491432)'), '-3783221712113945500': CallNode(function='metadsl_core.abstraction.Abstraction.create_variable', type_params={'U': DeclaredTypeInstance(type='metadsl_core.abstraction.Abstraction', params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}), 'T': DeclaredTypeInstance(type='metadsl_core.abstraction.Abstraction', params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)})}, args=['6845283599498181972'], kwargs=None), '8691569820795597478': PrimitiveNode(type='function', repr='<function FunctionOne.from_fn_recursive.<locals>.inner.<locals>.inner_inner at 0x10e1a8730>'), '7907080515730425835': CallNode(function='metadsl_core.abstraction.Abstraction.from_fn', type_params=None, args=['8691569820795597478'], kwargs=None), '-8103225364630033322': CallNode(function='metadsl_core.abstraction.Abstraction.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.abstraction.Abstraction', params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}), 'T': DeclaredTypeInstance(type='metadsl_core.abstraction.Abstraction', params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)})}, args=['-3783221712113945500', '7907080515730425835'], kwargs=None), '-872858781194512288': CallNode(function='metadsl_core.abstraction.Abstraction.fix', type_params=None, args=['-8103225364630033322'], kwargs=None), '7450205441077331797': CallNode(function='metadsl_core.function.FunctionOne.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integ ...
# PASSED
# metadsl_core/function_test.py::TestFunction::test_two_abstraction
# Typez(definitions=None, nodes={'-531802216116552155': PrimitiveNode(type='function', repr='<function TestFunction.test_two_abstraction.<locals>.add at 0x10e1a8268>'), '7766742547459609125': CallNode(function='metadsl_core.function.FunctionTwo.from_fn', type_params=None, args=['-531802216116552155'], kwargs=None), '-4358252360680294696': CallNode(function='metadsl_core.function.FunctionTwo.abstraction', type_params={'V': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['7766742547459609125'], kwargs=None), '-2870914343228046508': PrimitiveNode(type='str', repr="'add'"), '-531802216283261005': PrimitiveNode(type='function', repr='<function FunctionTwo.from_fn.<locals>.inner at 0x10e1a88c8>'), '-3757258798293565303': CallNode(function='metadsl_core.abstraction.Abstraction.from_fn', type_params=None, args=['-531802216283261005'], kwargs=None), '7780060114893669685': CallNode(function='metadsl_core.function.FunctionTwo.create', type_params={'V': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-2870914343228046508', '-3757258798293565303'], kwargs=None), '3243927281261724273': CallNode(function='metadsl_core.function.FunctionTwo.abstraction', type_params={'V': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['7780060114893669685'], kwargs=None), '6845283562927239897': PrimitiveNode(type='metadsl_core.abstraction.Variable', repr='Variable(4531950872)'), '2900014907822033690': CallNode(function='metadsl_core.abstraction.Abstraction.create_variable', type_params={'U': DeclaredTypeInstance(type='metadsl_core.abstraction.Abstraction', params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['6845283562927239897'], kwargs=None), '8691569820562854603': PrimitiveNode(type='function', repr='<function FunctionTwo.from_fn.<locals>.inner.<locals>.inner_inner at 0x10e1a8840>'), '8675848828973567591': CallNode(function='metadsl_core.abstraction.Abstraction.from_fn', type_params=None, args=['8691569820562854603'], kwargs=None), '6951632123085561770': CallNode(function='metadsl_core.abstraction.Abstraction.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.abstraction.Abstraction', params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['2900014907822033690', '8675848828973567591'], kwargs=None), '6155142237782817879': CallNode(function='metadsl_core.function.FunctionTwo.create', type_params={'V': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-2870914343228046508', '6951632123085561770'], kwargs=None), '-2709094696535086743': CallNode(function='metadsl_core.function.FunctionTwo.abstraction', type_params={'V': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['6155142237782817879'], kwargs=None), '6845283589470752897': PrimitiveNode(type='metadsl_core ...
# PASSED
# metadsl_core/function_test.py::TestFunction::test_two_call
# Typez(definitions=None, nodes={'-531802216169595880': PrimitiveNode(type='function', repr='<function TestFunction.test_two_call.<locals>.add at 0x10e1a8158>'), '2349148190293303125': CallNode(function='metadsl_core.function.FunctionTwo.from_fn', type_params=None, args=['-531802216169595880'], kwargs=None), '-8909088244516912722': PrimitiveNode(type='int', repr='1'), '1014978254107297921': CallNode(function='metadsl_core.integer.Integer.from_int', type_params=None, args=['-8909088244516912722'], kwargs=None), '-8909088244520160297': PrimitiveNode(type='int', repr='2'), '-8837179201621905763': CallNode(function='metadsl_core.integer.Integer.from_int', type_params=None, args=['-8909088244520160297'], kwargs=None), '184102357667436989': CallNode(function='metadsl_core.function.FunctionTwo.__call__', type_params={'V': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['2349148190293303125', '1014978254107297921', '-8837179201621905763'], kwargs=None), '-2870914343228046508': PrimitiveNode(type='str', repr="'add'"), '-531802216198824055': PrimitiveNode(type='function', repr='<function FunctionTwo.from_fn.<locals>.inner at 0x10e1a8f28>'), '6898060463236003702': CallNode(function='metadsl_core.abstraction.Abstraction.from_fn', type_params=None, args=['-531802216198824055'], kwargs=None), '-6742813901413064104': CallNode(function='metadsl_core.function.FunctionTwo.create', type_params={'V': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-2870914343228046508', '6898060463236003702'], kwargs=None), '-4803339163011012272': CallNode(function='metadsl_core.function.FunctionTwo.__call__', type_params={'V': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-6742813901413064104', '1014978254107297921', '-8837179201621905763'], kwargs=None), '6845283549183502497': PrimitiveNode(type='metadsl_core.abstraction.Variable', repr='Variable(4532146072)'), '-3562651618031752163': CallNode(function='metadsl_core.abstraction.Abstraction.create_variable', type_params={'U': DeclaredTypeInstance(type='metadsl_core.abstraction.Abstraction', params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['6845283549183502497'], kwargs=None), '8691569930794210303': PrimitiveNode(type='function', repr='<function FunctionTwo.from_fn.<locals>.inner.<locals>.inner_inner at 0x10e25d400>'), '-5782199217675074890': CallNode(function='metadsl_core.abstraction.Abstraction.from_fn', type_params=None, args=['8691569930794210303'], kwargs=None), '-3879162600654086119': CallNode(function='metadsl_core.abstraction.Abstraction.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.abstraction.Abstraction', params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-3562651618031752163', '-5782199217675074890'], kwargs=None), '3714827555728062528': CallNode(function='metadsl_core.function.FunctionTwo.create', type_params={'V': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args= ...
# PASSED
# metadsl_core/function_test.py::TestFunction::test_three_recursive_call
# Typez(definitions=None, nodes={'-531802216169595880': PrimitiveNode(type='function', repr='<function TestFunction.test_three_recursive_call.<locals>.fib at 0x10e1a8158>'), '-1724716313866236761': CallNode(function='metadsl_core.function.FunctionOne.from_fn', type_params=None, args=['-531802216169595880'], kwargs=None), '-8909088244517995247': PrimitiveNode(type='int', repr='0'), '-4050196712294610884': CallNode(function='metadsl_core.integer.Integer.from_int', type_params=None, args=['-8909088244517995247'], kwargs=None), '6923823143942818616': CallNode(function='metadsl_core.function.FunctionOne.__call__', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-1724716313866236761', '-4050196712294610884'], kwargs=None), '-6302723909931771071': PrimitiveNode(type='str', repr="'fib'"), '-531802216034280255': PrimitiveNode(type='function', repr='<function TestFunction.test_three_recursive_call.<locals>.fib at 0x10e1a86a8>'), '-2978048976017938914': CallNode(function='metadsl_core.abstraction.Abstraction.from_fn', type_params=None, args=['-531802216034280255'], kwargs=None), '1129790513858186616': CallNode(function='metadsl_core.function.FunctionOne.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-6302723909931771071', '-2978048976017938914'], kwargs=None), '4984498346228447702': CallNode(function='metadsl_core.function.FunctionOne.__call__', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['1129790513858186616', '-4050196712294610884'], kwargs=None), '6845283683664500722': PrimitiveNode(type='metadsl_core.abstraction.Variable', repr='Variable(4531769416)'), '-6734860151188027357': CallNode(function='metadsl_core.abstraction.Abstraction.create_variable', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['6845283683664500722'], kwargs=None), '-531802216246455155': PrimitiveNode(type='function', repr='<function TestFunction.test_three_recursive_call.<locals>.fib_more at 0x10e1a8ae8>'), '8733307076112758591': CallNode(function='metadsl_core.function.FunctionThree.from_fn_recursive', type_params=None, args=['-531802216246455155'], kwargs=None), '-8909088244516912722': PrimitiveNode(type='int', repr='1'), '1014978254107297921': CallNode(function='metadsl_core.integer.Integer.from_int', type_params=None, args=['-8909088244516912722'], kwargs=None), '-9076497909734148942': CallNode(function='metadsl_core.function.FunctionThree.__call__', type_params={'X': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'V': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['8733307076112758591', '-6734860151188027357', '-4050196712294610884', '1014978254107297921'], kwargs=None), '-9141922173503442915': CallNode(function='metadsl_core.abstraction.Abstraction.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-6734860151188027357', '-9076497909734148942'], kwargs=None), '-5933333044409993009': CallNode(function='metadsl_core.function.FunctionOne.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-6302723909931771071', '-9141922173503442915'], kwargs=None), '-4044674202272585829': CallNode(funct ...
# Typez(definitions=None, nodes={'-531802216169595880': PrimitiveNode(type='function', repr='<function TestFunction.test_three_recursive_call.<locals>.fib at 0x10e1a8158>'), '-1724716313866236761': CallNode(function='metadsl_core.function.FunctionOne.from_fn', type_params=None, args=['-531802216169595880'], kwargs=None), '-8909088244516912722': PrimitiveNode(type='int', repr='1'), '1014978254107297921': CallNode(function='metadsl_core.integer.Integer.from_int', type_params=None, args=['-8909088244516912722'], kwargs=None), '3184616891925334022': CallNode(function='metadsl_core.function.FunctionOne.__call__', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-1724716313866236761', '1014978254107297921'], kwargs=None), '-6302723909931771071': PrimitiveNode(type='str', repr="'fib'"), '8691569930701113153': PrimitiveNode(type='function', repr='<function TestFunction.test_three_recursive_call.<locals>.fib at 0x10e25dea0>'), '-3889220309019611037': CallNode(function='metadsl_core.abstraction.Abstraction.from_fn', type_params=None, args=['8691569930701113153'], kwargs=None), '-7589530569484936235': CallNode(function='metadsl_core.function.FunctionOne.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-6302723909931771071', '-3889220309019611037'], kwargs=None), '3091508565450651026': CallNode(function='metadsl_core.function.FunctionOne.__call__', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-7589530569484936235', '1014978254107297921'], kwargs=None), '6845283677720355947': PrimitiveNode(type='metadsl_core.abstraction.Variable', repr='Variable(4531816824)'), '-2700440534751053689': CallNode(function='metadsl_core.abstraction.Abstraction.create_variable', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['6845283677720355947'], kwargs=None), '8691569820711160528': PrimitiveNode(type='function', repr='<function TestFunction.test_three_recursive_call.<locals>.fib_more at 0x10e1a80d0>'), '5833891742102043431': CallNode(function='metadsl_core.function.FunctionThree.from_fn_recursive', type_params=None, args=['8691569820711160528'], kwargs=None), '-8909088244517995247': PrimitiveNode(type='int', repr='0'), '-4050196712294610884': CallNode(function='metadsl_core.integer.Integer.from_int', type_params=None, args=['-8909088244517995247'], kwargs=None), '-5631380493005677432': CallNode(function='metadsl_core.function.FunctionThree.__call__', type_params={'X': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'V': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['5833891742102043431', '-2700440534751053689', '-4050196712294610884', '1014978254107297921'], kwargs=None), '-8255250269777279598': CallNode(function='metadsl_core.abstraction.Abstraction.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-2700440534751053689', '-5631380493005677432'], kwargs=None), '-4033617353074923948': CallNode(function='metadsl_core.function.FunctionOne.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-6302723909931771071', '-8255250269777279598'], kwargs=None), '-6978802929945455322': CallNode(funct ...
# Typez(definitions=None, nodes={'-531802216169595880': PrimitiveNode(type='function', repr='<function TestFunction.test_three_recursive_call.<locals>.fib at 0x10e1a8158>'), '-1724716313866236761': CallNode(function='metadsl_core.function.FunctionOne.from_fn', type_params=None, args=['-531802216169595880'], kwargs=None), '-8909088244526655447': PrimitiveNode(type='int', repr='8'), '-6236103780076709370': CallNode(function='metadsl_core.integer.Integer.from_int', type_params=None, args=['-8909088244526655447'], kwargs=None), '1985222423524326064': CallNode(function='metadsl_core.function.FunctionOne.__call__', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-1724716313866236761', '-6236103780076709370'], kwargs=None), '-6302723909931771071': PrimitiveNode(type='str', repr="'fib'"), '8691569820811835353': PrimitiveNode(type='function', repr='<function TestFunction.test_three_recursive_call.<locals>.fib at 0x10e1a8620>'), '5424575901262407439': CallNode(function='metadsl_core.abstraction.Abstraction.from_fn', type_params=None, args=['8691569820811835353'], kwargs=None), '-4248679271475342371': CallNode(function='metadsl_core.function.FunctionOne.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-6302723909931771071', '5424575901262407439'], kwargs=None), '-6063699540537822925': CallNode(function='metadsl_core.function.FunctionOne.__call__', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-4248679271475342371', '-6236103780076709370'], kwargs=None), '-2378088464776952086': PrimitiveNode(type='metadsl_core.abstraction.Variable', repr='Variable(4532364736)'), '-1011741401699098934': CallNode(function='metadsl_core.abstraction.Abstraction.create_variable', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-2378088464776952086'], kwargs=None), '8691569820711160528': PrimitiveNode(type='function', repr='<function TestFunction.test_three_recursive_call.<locals>.fib_more at 0x10e1a80d0>'), '5833891742102043431': CallNode(function='metadsl_core.function.FunctionThree.from_fn_recursive', type_params=None, args=['8691569820711160528'], kwargs=None), '-8909088244517995247': PrimitiveNode(type='int', repr='0'), '-4050196712294610884': CallNode(function='metadsl_core.integer.Integer.from_int', type_params=None, args=['-8909088244517995247'], kwargs=None), '-8909088244516912722': PrimitiveNode(type='int', repr='1'), '1014978254107297921': CallNode(function='metadsl_core.integer.Integer.from_int', type_params=None, args=['-8909088244516912722'], kwargs=None), '-2864144331184871567': CallNode(function='metadsl_core.function.FunctionThree.__call__', type_params={'X': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'V': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['5833891742102043431', '-1011741401699098934', '-4050196712294610884', '1014978254107297921'], kwargs=None), '6073465695154221384': CallNode(function='metadsl_core.abstraction.Abstraction.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-1011741401699098934', '-2864144331184871567'], kwargs=None), '5148757430042658444': CallNode(function='metadsl_core.function.FunctionOne.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.I ...
# PASSED
#
# ====================================================== 4 passed in 25.95 seconds ======================================================
