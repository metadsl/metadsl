# %% [markdown]
# # Tests
# In this notebook, we run our `pytest` test suite. Why would we run this in a notebook not from the command line? Because then  we can visualize the replacemnts as they happen for debugging

# %%
import pytest
import metadsl_visualize
DISABLED_PLUGINS = [
    "xdist",
    "mypy",
    "pudb",
    "testmon",
    "randomly",
    "forked"
]

def test(path=""):
    pytest.main([l for p in DISABLED_PLUGINS for l in ("-p", f"no:{p}")] + ["-v", "-s", path])
    
test("../metadsl_llvm/integration_test.py::test_add")
# Out:
# ======================================================================================================================================= test session starts =======================================================================================================================================
# platform darwin -- Python 3.7.3, pytest-5.3.1, py-1.8.0, pluggy-0.13.1 -- /usr/local/Caskroom/miniconda/base/envs/metadsl/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/saul/p/metadsl, inifile: pytest.ini
# plugins: xdist-1.30.0, metadsl_visualize-0.1.0, cov-2.8.1
# collecting ... collected 1 item
#
# ../metadsl_llvm/integration_test.py::test_add
# Typez(definitions=None, nodes={'-5273443887687814700': ['103', PrimitiveNode(type='str', repr='add')], '-1872693081566434442': ['104', CallNode(function='ModRef.create', type_params=None, args=['-5273443887687814700'], kwargs=None)], '7016207301674886600': ['105', PrimitiveNode(type='int', repr='32')], '2870338159802749340': ['106', CallNode(function='Type.create_int', type_params=None, args=['7016207301674886600'], kwargs=None)], '934639236562537624': ['107', CallNode(function='FnType.create', type_params=None, args=['2870338159802749340', '2870338159802749340', '2870338159802749340'], kwargs=None)], '6454579929412599094': ['108', PrimitiveNode(type='str', repr='fastcc')], '30598887731649015': ['109', CallNode(function='ModRef.function_', type_params=None, args=['-1872693081566434442', '-5273443887687814700', '934639236562537624', '6454579929412599094'], kwargs=None)], '7021871089430475675': ['110', PrimitiveNode(type='bool', repr='True')], '7063788122855134750': ['111', PrimitiveNode(type='NoneType', repr='None')], '-2715567023190465170': ['112', PrimitiveNode(type='_Uniq', repr='140489731076280')], '-6182516854502946284': ['113', CallNode(function='FnRef._block', type_params=None, args=['30598887731649015', '7021871089430475675', '7063788122855134750', '-2715567023190465170'], kwargs=None)], '4294441534185810464': ['114', CallNode(function='FnRef.arguments', type_params=None, args=['30598887731649015'], kwargs=None)], '7016207301640245800': ['115', PrimitiveNode(type='int', repr='0')], '-1571579589986871854': ['116', CallNode(function='Integer.from_int', type_params=None, args=['7016207301640245800'], kwargs=None)], '-2604415589253009182': ['117', CallNode(function='Vec.__getitem__', type_params={'T': DeclaredTypeInstance(type='Value', params=None)}, args=['4294441534185810464', '-1571579589986871854'], kwargs=None)], '7016207301639163275': ['118', PrimitiveNode(type='int', repr='1')], '-5915110327689571789': ['119', CallNode(function='Integer.from_int', type_params=None, args=['7016207301639163275'], kwargs=None)], '-8927013919712076097': ['120', CallNode(function='Vec.__getitem__', type_params={'T': DeclaredTypeInstance(type='Value', params=None)}, args=['4294441534185810464', '-5915110327689571789'], kwargs=None)], '-8789246194224116341': ['121', CallNode(function='BlockRef.add', type_params=None, args=['-6182516854502946284', '-2604415589253009182', '-8927013919712076097'], kwargs=None)], '1171518408186409166': ['122', CallNode(function='Value.constant', type_params=None, args=['2870338159802749340', '7016207301639163275'], kwargs=None)], '-4675899100260917532': ['123', CallNode(function='BlockRef.add', type_params=None, args=['-6182516854502946284', '-8789246194224116341', '1171518408186409166'], kwargs=None)], '-3104987497168150496': ['124', CallNode(function='BlockRef.ret', type_params=None, args=['-6182516854502946284', '-4675899100260917532'], kwargs=None)], '8020772244198886670': ['125', CallNode(function='Vec.create', type_params=None, args=['-3104987497168150496'], kwargs=None)], '-305607696542352989': ['126', CallNode(function='Fn.create', type_params=None, args=['8020772244198886670'], kwargs=None)], '1556613773680639194': ['57', CallNode(function='Vec.create', type_params=None, args=['-305607696542352989'], kwargs=None)], '5009726762799974318': ['56', CallNode(function='Mod.create', type_params=None, args=['1556613773680639194'], kwargs=None)], '-8819251979157799981': ['29', CallNode(function='CType.c_int', type_params=None, args=None, kwargs=None)], '-7567502986332595920': ['30', CallNode(function='CFunctionType.create', type_params=None, args=['-8819251979157799981', '-8819251979157799981'], kwargs=None)], '7951621600664249198': ['28', CallNode(function='compile_function', type_params=None, args=['5009726762799974318', '-1872693081566434442', '30598887731649015', '-7567502986332595920', '7016207301639163275'], kwargs=None)], '6711118386559389318': ['57', CallNode(function='Mod.functions', type_params=None,  ...
# FAILED
#
# ============================================================================================================================================ FAILURES =============================================================================================================================================
# ____________________________________________________________________________________________________________________________________________ test_add _____________________________________________________________________________________________________________________________________________
#
#     def test_add():
#         ##
#         # Constants
#         ##
#
#         int_type = ml.Type.create_int(32)
#         one = ml.Value.constant(int_type, 1)
#
#         mod_ref = ml.ModRef.create("add")
#         fn_ref = mod_ref.function_(
#             "add", ml.FnType.create(int_type, int_type, int_type), "fastcc",
#         )
#
#         l = fn_ref.arguments[mc.Integer.from_int(0)]
#         r = fn_ref.arguments[mc.Integer.from_int(1)]
#
#         block_ref = fn_ref.block(True)
#         lr = block_ref.add(l, r)
#         res = block_ref.add(lr, one)
#         terminate = block_ref.ret(res)
#
#         fn = ml.Fn.create(mc.Vec.create(terminate))
#
#         mod = ml.Mod.create(mc.Vec.create(fn))
#
#         c_int = ml.CType.c_int()
#         c_func_type = ml.CFunctionType.create(c_int, c_int)
#
#         real_fn = m.execute(ml.compile_function(mod, mod_ref, fn_ref, c_func_type))
# >       assert real_fn(10) == 21
# E       TypeError: 'PlaceholderExpression' object is not callable
#
# ../metadsl_llvm/integration_test.py:142: TypeError
# ======================================================================================================================================== 1 failed in 2.84s ========================================================================================================================================
