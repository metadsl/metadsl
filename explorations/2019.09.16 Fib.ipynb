# %%
from metadsl import *
from metadsl_core import *
import metadsl_visualize

# %%
one = Integer.from_int(1)
zero = Integer.from_int(0)


@FunctionThree.from_fn_recursive
def fib_more(
    fn: FunctionThree[Integer, Integer, Integer, Integer],
    n: Integer,
    a: Integer,
    b: Integer,
) -> Integer:
    pred_cont = n > one
    minus1 = n - one
    ab = a + b
    added = fn(minus1, b, ab)

    n_eq_1 = n.eq(one)
    return pred_cont.if_(added, n_eq_1.if_(b, a))

@FunctionOne.from_fn
def fib(n: Integer) -> Integer:
    return fib_more(n, zero, one)

# %%
fib(Integer.from_int(10))
# Out:
# Typez(definitions=None, nodes={'-6418131642251509616': ['-6418131642251509616', PrimitiveNode(type='function', repr='<function fib at 0x110bfcd08>')], '8673626991110420942': ['8673626991110420942', CallNode(function='FunctionOne.from_fn', type_params=None, args=['-6418131642251509616'], kwargs=None)], '-6419023128754974491': ['-6419023128754974491', PrimitiveNode(type='int', repr='10')], '6103801433172996860': ['6103801433172996860', CallNode(function='Integer.from_int', type_params=None, args=['-6419023128754974491'], kwargs=None)], '318040313884840776': ['318040313884840776', CallNode(function='FunctionOne.__call__', type_params={'U': DeclaredTypeInstance(type='Integer', params=None), 'T': DeclaredTypeInstance(type='Integer', params=None)}, args=['8673626991110420942', '6103801433172996860'], kwargs=None)], '2744678702015246265': ['2744678702015246265', PrimitiveNode(type='str', repr="'fib'")], '-6418118924811678591': ['-6418118924811678591', PrimitiveNode(type='function', repr='<function fib at 0x11b8be378>')], '248918945970308413': ['248918945970308413', CallNode(function='Abstraction.from_fn', type_params=None, args=['-6418118924811678591'], kwargs=None)], '2030819026340777149': ['8673626991110420942', CallNode(function='FunctionOne.create', type_params={'U': DeclaredTypeInstance(type='Integer', params=None), 'T': DeclaredTypeInstance(type='Integer', params=None)}, args=['2744678702015246265', '248918945970308413'], kwargs=None)], '-1149810487255509148': ['318040313884840776', CallNode(function='FunctionOne.__call__', type_params={'U': DeclaredTypeInstance(type='Integer', params=None), 'T': DeclaredTypeInstance(type='Integer', params=None)}, args=['2030819026340777149', '6103801433172996860'], kwargs=None)], '6474370575868379729': ['6474370575868379729', PrimitiveNode(type='Variable', repr='Variable(4757108664)')], '-744199890971632850': ['-744199890971632850', CallNode(function='Abstraction.create_variable', type_params={'U': DeclaredTypeInstance(type='Integer', params=None), 'T': DeclaredTypeInstance(type='Integer', params=None)}, args=['6474370575868379729'], kwargs=None)], '-6418118924771625166': ['-6418118924771625166', PrimitiveNode(type='function', repr='<function fib_more at 0x11b8be6a8>')], '1385772832083853115': ['1385772832083853115', CallNode(function='FunctionThree.from_fn_recursive', type_params=None, args=['-6418118924771625166'], kwargs=None)], '-6419023128748479341': ['-6419023128748479341', PrimitiveNode(type='int', repr='0')], '-7780010268360885738': ['839136460628675254', CallNode(function='Integer.from_int', type_params=None, args=['-6419023128748479341'], kwargs=None)], '-6419023128747396816': ['-6419023128747396816', PrimitiveNode(type='int', repr='1')], '-8669076885534315835': ['-8669076885534315835', CallNode(function='Integer.from_int', type_params=None, args=['-6419023128747396816'], kwargs=None)], '3769914166898782292': ['3769914166898782292', CallNode(function='FunctionThree.__call__', type_params={'X': DeclaredTypeInstance(type='Integer', params=None), 'V': DeclaredTypeInstance(type='Integer', params=None), 'U': DeclaredTypeInstance(type='Integer', params=None), 'T': DeclaredTypeInstance(type='Integer', params=None)}, args=['1385772832083853115', '-744199890971632850', '-7780010268360885738', '-8669076885534315835'], kwargs=None)], '-7480853256703681953': ['248918945970308413', CallNode(function='Abstraction.create', type_params={'U': DeclaredTypeInstance(type='Integer', params=None), 'T': DeclaredTypeInstance(type='Integer', params=None)}, args=['-744199890971632850', '3769914166898782292'], kwargs=None)], '612439864472473658': ['8673626991110420942', CallNode(function='FunctionOne.create', type_params={'U': DeclaredTypeInstance(type='Integer', params=None), 'T': DeclaredTypeInstance(type='Integer', params=None)}, args=['2744678702015246265', '-7480853256703681953'], kwargs=None)], '1924932590202147815': ['318040313884840776', CallNode(function='FunctionOne.__call__', type_params={'U': Decla ...
