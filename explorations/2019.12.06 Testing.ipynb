# %% [markdown]
# # Tests
# In this notebook, we run our `pytest` test suite. Why would we run this in a notebook not from the command line? Because then  we can visualize the replacemnts as they happen for debugging

# %%
import pytest
import metadsl_visualize
DISABLED_PLUGINS = [
    "xdist",
    "mypy",
    "pudb",
    "testmon",
    "randomly",
    "forked"
]

def test(path=""):
    pytest.main([l for p in DISABLED_PLUGINS for l in ("-p", f"no:{p}")] + ["-v", "-s", path])
    
test("metadsl_core/function_test.py::TestFunction::test_three_recursive_call")
# Out:
# ============================================================================================================================= test session starts ==============================================================================================================================
# platform darwin -- Python 3.7.3, pytest-4.4.0, py-1.8.0, pluggy-0.9.0 -- /usr/local/miniconda3/envs/metadsl/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/saul/p/metadsl, inifile: pytest.ini
# plugins: xdist-1.29.0, cov-2.6.1, nbval-0.9.1, metadsl-visualize-0.0.0
# collecting ... collected 1 item
#
# metadsl_core/function_test.py::TestFunction::test_three_recursive_call
# Typez(definitions=None, nodes={'4806914314038272558': PrimitiveNode(type='function', repr='<function TestFunction.test_three_recursive_call.<locals>.fib at 0x112dc4400>'), '3669478004075634260': CallNode(function='metadsl_core.function.FunctionOne.from_fn', type_params=None, args=['4806914314038272558'], kwargs=None), '1034006784353213760': PrimitiveNode(type='int', repr='0'), '-4234317956595644042': CallNode(function='metadsl_core.integer.Integer.from_int', type_params=None, args=['1034006784353213760'], kwargs=None), '-7158175557925470817': CallNode(function='metadsl_core.function.FunctionOne.__call__', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['3669478004075634260', '-4234317956595644042'], kwargs=None), '5903805328135675821': PrimitiveNode(type='str', repr="'fib'"), '-4416457722825163450': PrimitiveNode(type='function', repr='<function TestFunction.test_three_recursive_call.<locals>.fib at 0x112dc4488>'), '3233960080530032650': CallNode(function='metadsl_core.abstraction.Abstraction.from_fn', type_params=None, args=['-4416457722825163450'], kwargs=None), '-2286270642451695489': CallNode(function='metadsl_core.function.FunctionOne.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['5903805328135675821', '3233960080530032650'], kwargs=None), '-1150583558637706589': CallNode(function='metadsl_core.function.FunctionOne.__call__', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-2286270642451695489', '-4234317956595644042'], kwargs=None), '2639609531874952986': PrimitiveNode(type='metadsl_core.abstraction.Variable', repr='Variable(4611496312)'), '8299775114115455472': CallNode(function='metadsl_core.abstraction.Abstraction.create_variable', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['2639609531874952986'], kwargs=None), '4806914314241787258': PrimitiveNode(type='function', repr='<function TestFunction.test_three_recursive_call.<locals>.fib_more at 0x112dc4840>'), '7731990144071340484': CallNode(function='metadsl_core.function.FunctionThree.from_fn_recursive', type_params=None, args=['4806914314241787258'], kwargs=None), '1034006784352131235': PrimitiveNode(type='int', repr='1'), '-8709542130944361733': CallNode(function='metadsl_core.integer.Integer.from_int', type_params=None, args=['1034006784352131235'], kwargs=None), '-1475391399396381277': CallNode(function='metadsl_core.function.FunctionThree.__call__', type_params={'X': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'V': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['7731990144071340484', '8299775114115455472', '-4234317956595644042', '-8709542130944361733'], kwargs=None), '509258354125379418': CallNode(function='metadsl_core.abstraction.Abstraction.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['8299775114115455472', '-1475391399396381277'], kwargs=None), '-6252778299115590961': CallNode(function='metadsl_core.function.FunctionOne.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['5903805328135675821', '509258354125379418'], kwargs=None), '-6658775143122209548': CallNode(function='metad ...
# Typez(definitions=None, nodes={'4806914314038272558': PrimitiveNode(type='function', repr='<function TestFunction.test_three_recursive_call.<locals>.fib at 0x112dc4400>'), '3669478004075634260': CallNode(function='metadsl_core.function.FunctionOne.from_fn', type_params=None, args=['4806914314038272558'], kwargs=None), '1034006784352131235': PrimitiveNode(type='int', repr='1'), '-8709542130944361733': CallNode(function='metadsl_core.integer.Integer.from_int', type_params=None, args=['1034006784352131235'], kwargs=None), '4184490951888215649': CallNode(function='metadsl_core.function.FunctionOne.__call__', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['3669478004075634260', '-8709542130944361733'], kwargs=None), '5903805328135675821': PrimitiveNode(type='str', repr="'fib'"), '-4416457722751551750': PrimitiveNode(type='function', repr='<function TestFunction.test_three_recursive_call.<locals>.fib at 0x112dc4048>'), '-8917889972406205504': CallNode(function='metadsl_core.abstraction.Abstraction.from_fn', type_params=None, args=['-4416457722751551750'], kwargs=None), '-3009899886429764399': CallNode(function='metadsl_core.function.FunctionOne.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['5903805328135675821', '-8917889972406205504'], kwargs=None), '997931436393516042': CallNode(function='metadsl_core.function.FunctionOne.__call__', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-3009899886429764399', '-8709542130944361733'], kwargs=None), '2639609697380035186': PrimitiveNode(type='metadsl_core.abstraction.Variable', repr='Variable(4611667448)'), '-7768410922738826923': CallNode(function='metadsl_core.abstraction.Abstraction.create_variable', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['2639609697380035186'], kwargs=None), '4806914412564285433': PrimitiveNode(type='function', repr='<function TestFunction.test_three_recursive_call.<locals>.fib_more at 0x112e67d90>'), '3282368643820575592': CallNode(function='metadsl_core.function.FunctionThree.from_fn_recursive', type_params=None, args=['4806914412564285433'], kwargs=None), '1034006784353213760': PrimitiveNode(type='int', repr='0'), '-4234317956595644042': CallNode(function='metadsl_core.integer.Integer.from_int', type_params=None, args=['1034006784353213760'], kwargs=None), '-4899339545430744691': CallNode(function='metadsl_core.function.FunctionThree.__call__', type_params={'X': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'V': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['3282368643820575592', '-7768410922738826923', '-4234317956595644042', '-8709542130944361733'], kwargs=None), '8295383731141199096': CallNode(function='metadsl_core.abstraction.Abstraction.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-7768410922738826923', '-4899339545430744691'], kwargs=None), '4026712257252816553': CallNode(function='metadsl_core.function.FunctionOne.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['5903805328135675821', '8295383731141199096'], kwargs=None), '1616311534761035317': CallNode(function='met ...
# Typez(definitions=None, nodes={'4806914314038272558': PrimitiveNode(type='function', repr='<function TestFunction.test_three_recursive_call.<locals>.fib at 0x112dc4400>'), '3669478004075634260': CallNode(function='metadsl_core.function.FunctionOne.from_fn', type_params=None, args=['4806914314038272558'], kwargs=None), '1034006784344553560': PrimitiveNode(type='int', repr='8'), '656907159870866161': CallNode(function='metadsl_core.integer.Integer.from_int', type_params=None, args=['1034006784344553560'], kwargs=None), '-5117623148474432865': CallNode(function='metadsl_core.function.FunctionOne.__call__', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['3669478004075634260', '656907159870866161'], kwargs=None), '5903805328135675821': PrimitiveNode(type='str', repr="'fib'"), '-4416457722702838125': PrimitiveNode(type='function', repr='<function TestFunction.test_three_recursive_call.<locals>.fib at 0x112dc4378>'), '6737744210834326803': CallNode(function='metadsl_core.abstraction.Abstraction.from_fn', type_params=None, args=['-4416457722702838125'], kwargs=None), '-6099406227013109068': CallNode(function='metadsl_core.function.FunctionOne.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['5903805328135675821', '6737744210834326803'], kwargs=None), '2732668372408927307': CallNode(function='metadsl_core.function.FunctionOne.__call__', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-6099406227013109068', '656907159870866161'], kwargs=None), '-6583762350870481297': PrimitiveNode(type='metadsl_core.abstraction.Variable', repr='Variable(4611803008)'), '-294401117194656268': CallNode(function='metadsl_core.abstraction.Abstraction.create_variable', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-6583762350870481297'], kwargs=None), '4806914412548047558': PrimitiveNode(type='function', repr='<function TestFunction.test_three_recursive_call.<locals>.fib_more at 0x112e67c80>'), '6023470204736570997': CallNode(function='metadsl_core.function.FunctionThree.from_fn_recursive', type_params=None, args=['4806914412548047558'], kwargs=None), '1034006784353213760': PrimitiveNode(type='int', repr='0'), '-4234317956595644042': CallNode(function='metadsl_core.integer.Integer.from_int', type_params=None, args=['1034006784353213760'], kwargs=None), '1034006784352131235': PrimitiveNode(type='int', repr='1'), '-8709542130944361733': CallNode(function='metadsl_core.integer.Integer.from_int', type_params=None, args=['1034006784352131235'], kwargs=None), '-6856364089336328834': CallNode(function='metadsl_core.function.FunctionThree.__call__', type_params={'X': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'V': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['6023470204736570997', '-294401117194656268', '-4234317956595644042', '-8709542130944361733'], kwargs=None), '-8406597273627504706': CallNode(function='metadsl_core.abstraction.Abstraction.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None), 'T': DeclaredTypeInstance(type='metadsl_core.integer.Integer', params=None)}, args=['-294401117194656268', '-6856364089336328834'], kwargs=None), '5908307872142292155': CallNode(function='metadsl_core.function.FunctionOne.create', type_params={'U': DeclaredTypeInstance(type='metadsl_core.integer.Integer', param ...
# PASSED
#
# ========================================================================================================================== 1 passed in 21.48 seconds ===========================================================================================================================
