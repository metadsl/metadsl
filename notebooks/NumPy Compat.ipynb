# %% [markdown]
# # `uarray` NumPy Compatability

# %%
from uarray import *
import numpy as np
import numba

# %% [markdown]
# ## Original Expression

# %% [markdown]
# Let's look at this simple NumPy expression of calling the outer production of two values and then indexing it:

# %%
def some_fn(a, b):
    return np.multiply.outer(a, b)[5]

# %% [markdown]
# We can see that this does a lot of extra work, since we discard most of the results of the outer product after indexing. We can look at the time:

# %%
args = [np.arange(10000), np.arange(10000)]

# %%
some_fn(*args)
# Out:
# array([    0,     5,    10, ..., 49985, 49990, 49995])

# %%
# NBVAL_IGNORE_OUTPUT
# %timeit some_fn(*args)
# Out:
# 747 ms ± 50 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## Uarray reduced

# %% [markdown]
# Now let's use uarray's `jit` decorator to create an updated function that specifes the dimensionality of the arrays to produced an optimized form:

# %%
optimized_some_fn = jit(1, 1)(some_fn)
optimized_some_fn(*args)
# Out:
# Array(value=Operation(name=<function _as_ast at 0x10a49a9d8>, args=(Abstraction(value=NativeAbstraction(fn=Partial(fn=<bound method Abstraction._create_nary_inner of <class 'uarray.core.abstractions.Abstraction'>>, args=(Partial(fn=<function _ast_abstraction_inner at 0x10a49a7b8>, args=(<function to_ast__from_list_nd.<locals>.inner at 0x119292a60>, Array(value=Operation(name=<function Array.from_list_nd at 0x1092261e0>, args=(List(value=Operation(name=<function Natural.loop at 0x109204ea0>, args=(Natural(value=AST(get=<_ast.Subscript object at 0x1192ff898>, init=())), List(value=Operation(name=<function create_empty at 0x10a494f28>, args=(Box(value=None), Natural(value=AST(get=<_ast.Subscript object at 0x1192ff898>, init=()))), concrete=False), dtype=Box(value=None)), Abstraction(value=Operation(name=<function Abstraction.from_variable at 0x1091e6bf8>, args=(List(value=Variable(name=None), dtype=Box(value=None)), Abstraction(value=Operation(name=<function Abstraction.from_variable at 0x1091e6bf8>, args=(Natural(value=Variable(name=None)), List(value=Operation(name=<function set_item at 0x10a49a048>, args=(List(value=Variable(name=None), dtype=Box(value=None)), Natural(value=Variable(name=None)), Box(value=Operation(name=<function numpy_ufunc at 0x10a494840>, args=(Box(value=<ufunc 'multiply'>), Box(value=AST(get=<_ast.Subscript object at 0x1192d9cf8>, init=())), Box(value=Operation(name=<function Abstraction.__call__ at 0x1091e6a60>, args=(Abstraction(value=NativeAbstraction(fn=Partial(fn=<bound method Abstraction._create_nary_inner of <class 'uarray.core.abstractions.Abstraction'>>, args=(Partial(fn=<function _ast_abstraction_inner at 0x10a49a7b8>, args=(<function _get_idx_abs.<locals>.idx_abs.<locals>.inner at 0x1192929d8>, Box(value=None))), Abstraction(value=None, rettype=Box(value=None)), ())), can_call=<function is_ast at 0x10923ab70>), rettype=Box(value=None)), Vec(value=Operation(name=<function _as_ast at 0x10a49a9d8>, args=(Abstraction(value=NativeAbstraction(fn=Partial(fn=<bound method Abstraction._create_nary_inner of <class 'uarray.core.abstractions.Abstraction'>>, args=(Partial(fn=<function _ast_abstraction_inner at 0x10a49a7b8>, args=(<function to_ast_tuple.<locals>.inner at 0x1091841e0>, Vec(value=Operation(name=<function Vec.create at 0x109215840>, args=(Natural(value=1), List(value=Operation(name=<function Vec._get_list at 0x109215b70>, args=(Vec(value=Variable(name=None), dtype=Natural(value=None)),), concrete=False), dtype=Natural(value=None))), concrete=True), dtype=Natural(value=None)))), Abstraction(value=None, rettype=Vec(value=Operation(name=<function Vec.create at 0x109215840>, args=(Natural(value=1), List(value=Operation(name=<function Vec._get_list at 0x109215b70>, args=(Vec(value=Variable(name=None), dtype=Natural(value=None)),), concrete=False), dtype=Natural(value=None))), concrete=True), dtype=Natural(value=None))), ())), can_call=<function is_ast at 0x10923ab70>), rettype=Vec(value=Operation(name=<function Vec.create at 0x109215840>, args=(Natural(value=1), List(value=Operation(name=<function Vec._get_list at 0x109215b70>, args=(Vec(value=Variable(name=None), dtype=Natural(value=None)),), concrete=False), dtype=Natural(value=None))), concrete=True), dtype=Natural(value=None))), Natural(value=Operation(name=<function Abstraction.__call__ at 0x1091e6a60>, args=(Abstraction(value=Operation(name=<function Vec._get_list at 0x109215b70>, args=(Vec(value=Operation(name=<function Array.gamma_inverse at 0x109226048>, args=(Natural(value=Variable(name=None)), Vec(value=Operation(name=<function Vec.create at 0x109215840>, args=(Natural(value=1), List(value=Operation(name=<function Abstraction.from_variable at 0x1091e6bf8>, args=(Natural(value=Variable(name=None)), Natural(value=Operation(name=<function _as_ast at 0x10a49a9d8>, args=(Abstraction(value=NativeAbstraction(fn=Partial(fn=<bound method Abstraction._create_nary_inner of <class 'uarray.core.abstractions.Abstraction'>>, args=(Partial(fn=<function _a ...
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-4-d836764f3452> in <module>
# ----> 1 optimized_some_fn = jit(1, 1)(some_fn)
#       2 optimized_some_fn(*args)
#
# /usr/local/miniconda3/envs/uarray/lib/python3.7/site-packages/uarray/optimize.py in inner(fn)
#      51
#      52             display(replaced)
# ---> 53             raise NotImplementedError("Couldn't compile to AST")
#      54         args_ = ast.arguments(
#      55             args=[ast.arg(arg=a, annotation=None) for a in arg_names],
#
# NotImplementedError: Couldn't compile to AST

# %%
# %timeit optimized_some_fn(*args)
# Out:
# 42.4 ms ± 136 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
numba_opt = numba.njit(optimized_some_fn)
numba_opt(*args)
# Out:
# array([    0,     5,    10, ..., 49985, 49990, 49995])

# %%
# %timeit numba_opt(*args)
# Out:
# 66.6 µs ± 7.83 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# Let's look at how this is done! First, we create an abstract representation of the array operations:

# %%
display_ops(optimized_some_fn.orig_res)

# %%
display_ops(optimized_some_fn.res)

# %%
display_ops(optimized_some_fn.new_res)

# %% [markdown]
# Then, we compile that to Python AST:

# %%
print(optimized_some_fn.source)
# Out:
# def fn(a, b):
#     v3 = numpy.empty(b.shape[0], dtype=numpy.int64)
#     for v2 in range(b.shape[0]):
#         v3[v2] = numpy.multiply(a[(5,)], b[((v2 % b.shape[(0 - 0)]),)])
#         v3 = v3
#     return v3.reshape((b.shape[0],))
