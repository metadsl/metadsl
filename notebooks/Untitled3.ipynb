# %%
from uarray import *
import numpy as np
import ast

# %%
a = Natural(AST(ast.Name("a", ast.Load())))
fn = Abstraction.create(lambda i: to_ast(i + Natural(2)), Natural())
visualize_progress(fn(Natural(1)), False)

# %%
fn
# Out:
# Abstraction(value=Operation(name=<function Abstraction.from_variable at 0x103942d08>, args=(Natural(value=Variable(name=None)), Natural(value=Operation(name=<function Natural.__add__ at 0x103967950>, args=(Natural(value=Variable(name=None)), Natural(value=2)), concrete=False))), concrete=True), rettype=Natural(value=None))

# %%
@jit(1)
def some_fn(a):
    return np.multiply.outer(a, a)

# %%
print(some_fn.source)
# Out:
# def fn(a):
#     v11 = numpy.empty((a.shape[0] * a.shape[(1 - 1)]), dtype=numpy.int64)
#     for v10 in range((a.shape[0] * a.shape[(1 - 1)])):
#         v11[v10] = numpy.multiply(a[(((v10 // a.shape[((1 - 0) - 1)]) % a.shape[(1 - 1)]),)], a[((v10 % a.shape[((1 - 0) - 1)]),)])
#         v11 = v11
#     return v11.reshape((a.shape[0], a.shape[(1 - 1)]))

# %%
shape_replaced = replace(some_fn.new_res.shape)
# display_ops(shape_replaced)
res = replace(shape_replaced[Natural(1)])
# display_ops(replace(res))
visualize_progress(shape_replaced[Natural(1)], False)
