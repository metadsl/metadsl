# %%
from metadsl import *
from metadsl_core import *
import metadsl_visualize

# %%
one = Integer.from_int(1)
zero = Integer.from_int(0)


@FunctionThree.from_fn_recursive
def fib_more(
    fn: FunctionThree[Integer, Integer, Integer, Integer],
    n: Integer,
    a: Integer,
    b: Integer,
) -> Integer:
    pred_cont = n > one
    minus1 = n - one
    ab = a + b
    added = fn(minus1, b, ab)

    n_eq_1 = n.eq(one)
    return pred_cont.if_(added, n_eq_1.if_(b, a))

@FunctionOne.from_fn
def fib(n: Integer) -> Integer:
    return fib_more(n, zero, one)

# %%
fib(Integer.from_int(10))
# Out:
# Typez(definitions=None, nodes={'776054082739656142': ['776054082739656142', PrimitiveNode(type='function', repr='<function fib at 0x1127f9a60>')], '5606899761833986078': ['5606899761833986078', CallNode(function='FunctionOne.from_fn', type_params=None, args=['776054082739656142'], kwargs=None)], '-8447594462450718491': ['-8447594462450718491', PrimitiveNode(type='int', repr='10')], '-6874163401516888138': ['-6874163401516888138', CallNode(function='Integer.from_int', type_params=None, args=['-8447594462450718491'], kwargs=None)], '8358276603824171253': ['8358276603824171253', CallNode(function='FunctionOne.__call__', type_params={'U': DeclaredTypeInstance(type='Integer', params=None), 'T': DeclaredTypeInstance(type='Integer', params=None)}, args=['5606899761833986078', '-6874163401516888138'], kwargs=None)], '-133344925089474753': ['-133344925089474753', PrimitiveNode(type='str', repr="'fib'")], '776052573083849417': ['776052573083849417', PrimitiveNode(type='function', repr='<function fib at 0x113c412f0>')], '-406885131121000982': ['-406885131121000982', CallNode(function='Abstraction.from_fn', type_params=None, args=['776052573083849417'], kwargs=None)], '230952450848075083': ['5606899761833986078', CallNode(function='FunctionOne.create', type_params={'U': DeclaredTypeInstance(type='Integer', params=None), 'T': DeclaredTypeInstance(type='Integer', params=None)}, args=['-133344925089474753', '-406885131121000982'], kwargs=None)], '-2889961612401835490': ['8358276603824171253', CallNode(function='FunctionOne.__call__', type_params={'U': DeclaredTypeInstance(type='Integer', params=None), 'T': DeclaredTypeInstance(type='Integer', params=None)}, args=['230952450848075083', '-6874163401516888138'], kwargs=None)], '8372212111313942376': ['8372212111313942376', PrimitiveNode(type='Variable', repr='Variable(4621321664)')], '-4989716468900071563': ['-4989716468900071563', CallNode(function='Abstraction.create_variable', type_params={'U': DeclaredTypeInstance(type='Integer', params=None), 'T': DeclaredTypeInstance(type='Integer', params=None)}, args=['8372212111313942376'], kwargs=None)], '-8447319463688654491': ['-8447319463688654491', PrimitiveNode(type='function', repr='<function fib_more at 0x113c417b8>')], '-4815054453429091667': ['-4815054453429091667', CallNode(function='FunctionThree.from_fn_recursive', type_params=None, args=['-8447319463688654491'], kwargs=None)], '-8447594462444223341': ['-8447594462444223341', PrimitiveNode(type='int', repr='0')], '-2203867892172421412': ['-6759338615018315753', CallNode(function='Integer.from_int', type_params=None, args=['-8447594462444223341'], kwargs=None)], '-8447594462443140816': ['-8447594462443140816', PrimitiveNode(type='int', repr='1')], '4869318742354101037': ['4869318742354101037', CallNode(function='Integer.from_int', type_params=None, args=['-8447594462443140816'], kwargs=None)], '3668255066523757261': ['3668255066523757261', CallNode(function='FunctionThree.__call__', type_params={'X': DeclaredTypeInstance(type='Integer', params=None), 'V': DeclaredTypeInstance(type='Integer', params=None), 'U': DeclaredTypeInstance(type='Integer', params=None), 'T': DeclaredTypeInstance(type='Integer', params=None)}, args=['-4815054453429091667', '-4989716468900071563', '-2203867892172421412', '4869318742354101037'], kwargs=None)], '-3222011659128617452': ['-406885131121000982', CallNode(function='Abstraction.create', type_params={'U': DeclaredTypeInstance(type='Integer', params=None), 'T': DeclaredTypeInstance(type='Integer', params=None)}, args=['-4989716468900071563', '3668255066523757261'], kwargs=None)], '-4113119819954724996': ['5606899761833986078', CallNode(function='FunctionOne.create', type_params={'U': DeclaredTypeInstance(type='Integer', params=None), 'T': DeclaredTypeInstance(type='Integer', params=None)}, args=['-133344925089474753', '-3222011659128617452'], kwargs=None)], '976162592481192558': ['8358276603824171253', CallNode(function='FunctionOne.__call__', type_params={'U':  ...
